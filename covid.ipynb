# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv('./dataset/bg-result-final-cleaned.csv')
# Out:
#            sadate       country_name  new_confirmed  cumulative_confirmed  \
# 0      2020-01-01        Afghanistan            0.0                   NaN
# 1      2020-01-01            Albania            0.0                   0.0
# 2      2020-01-01            Algeria            0.0                   0.0
# 3      2020-01-01     American Samoa            0.0                   0.0
# 4      2020-01-01            Andorra            0.0                   0.0
# ...           ...                ...            ...                   ...
# 61724  2020-12-31  Wallis and Futuna            0.0                   4.0
# 61725  2020-12-31     Western Sahara            0.0                   NaN
# 61726  2020-12-31              Yemen            2.0                2105.0
# 61727  2020-12-31             Zambia          272.0               20997.0
# 61728  2020-12-31           Zimbabwe          217.0               14084.0
#
#        new_deceased  cumulative_deceased  population   latitude   longitude
# ...
